# %%
import kagglehub
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import gc

# ==========================================
# 1. Download and Load Data
# ==========================================
print("=" * 50)
print("1. DOWNLOAD AND LOAD DATA")
print("=" * 50)

dataset_path = kagglehub.dataset_download("martinsn/high-frequency-crypto-limit-order-book-data")
print(f"Dataset path: {dataset_path}")

btc = pd.read_csv(os.path.join(dataset_path, 'BTC_1sec.csv'), nrows=100000)
eth = pd.read_csv(os.path.join(dataset_path, 'ETH_1sec.csv'), nrows=100000)
print(f"BTC shape: {btc.shape}")
print(f"ETH shape: {eth.shape}")
# Out:
# ==================================================
# 1. DOWNLOAD AND LOAD DATA
# ==================================================
# Using Colab cache for faster access to the 'high-frequency-crypto-limit-order-book-data' dataset.
# Dataset path: /kaggle/input/high-frequency-crypto-limit-order-book-data
# BTC shape: (100000, 156)
# ETH shape: (100000, 156)

# %%
# ==========================================
# 2. Time Alignment
# ==========================================
print("\n" + "=" * 50)
print("2. TIME ALIGNMENT")
print("=" * 50)

# Parse timestamps
btc['system_time'] = pd.to_datetime(btc['system_time'], utc=True)
eth['system_time'] = pd.to_datetime(eth['system_time'], utc=True)

# Floor to second to handle microsecond mismatch between BTC and ETH feeds
btc['time_key'] = btc['system_time'].dt.floor('s')
eth['time_key'] = eth['system_time'].dt.floor('s')

print(f"BTC time range: {btc['time_key'].min()} → {btc['time_key'].max()}")
print(f"ETH time range: {eth['time_key'].min()} → {eth['time_key'].max()}")

# Slim down ETH to only the columns needed for market features
eth_slim = eth[['time_key', 'midpoint', 'spread',
                 'bids_notional_0', 'asks_notional_0']].copy()
eth_slim = eth_slim.rename(columns={
    'midpoint':        'eth_midpoint',
    'spread':          'eth_spread',
    'bids_notional_0': 'eth_bids_notional_0',
    'asks_notional_0': 'eth_asks_notional_0',
})

# Inner join — only keep rows where both assets have data at the same second
df = pd.merge(btc, eth_slim, on='time_key', how='inner')
df = df.drop(columns=['time_key']).reset_index(drop=True)
df = df.drop(columns=['Unnamed: 0'])
df = df.set_index('system_time')
print(f"After merge: {df.shape}  ({len(df):,} rows retained)")
df.head()
# Out:
# ==================================================
# 2. TIME ALIGNMENT
# ==================================================
# BTC time range: 2021-04-07 11:32:42+00:00 → 2021-04-08 15:19:54+00:00
# ETH time range: 2021-04-07 11:32:50+00:00 → 2021-04-08 15:19:46+00:00
# After merge: (99972, 158)  (99,972 rows retained)
#                                    midpoint  spread  buys  sells  \
# system_time
# 2021-04-07 11:32:50.122161+00:00  56035.995    0.01   0.0    0.0
# 2021-04-07 11:32:51.122161+00:00  56035.995    0.01   0.0    0.0
# 2021-04-07 11:32:52.122161+00:00  56035.995    0.01   0.0    0.0
# 2021-04-07 11:32:53.122161+00:00  56035.995    0.01   0.0    0.0
# 2021-04-07 11:32:54.122161+00:00  56035.995    0.01   0.0    0.0
#
#                                   bids_distance_0  bids_distance_1  \
# system_time
# 2021-04-07 11:32:50.122161+00:00    -8.922836e-08    -2.676851e-07
# 2021-04-07 11:32:51.122161+00:00    -8.922836e-08    -2.676851e-07
# 2021-04-07 11:32:52.122161+00:00    -8.922836e-08    -2.676851e-07
# 2021-04-07 11:32:53.122161+00:00    -8.922836e-08    -2.676851e-07
# 2021-04-07 11:32:54.122161+00:00    -8.922836e-08    -2.676851e-07
#
#                                   bids_distance_2  bids_distance_3  \
# system_time
# 2021-04-07 11:32:50.122161+00:00         -0.00005        -0.000245
# 2021-04-07 11:32:51.122161+00:00         -0.00005        -0.000245
# 2021-04-07 11:32:52.122161+00:00         -0.00005        -0.000245
# 2021-04-07 11:32:53.122161+00:00         -0.00005        -0.000245
# 2021-04-07 11:32:54.122161+00:00         -0.00005        -0.000245
#
#                                   bids_distance_4  bids_distance_5  ...  \
# system_time                                                         ...
# 2021-04-07 11:32:50.122161+00:00        -0.000288        -0.000288  ...
# 2021-04-07 11:32:51.122161+00:00        -0.000288        -0.000288  ...
# 2021-04-07 11:32:52.122161+00:00        -0.000288        -0.000288  ...
# 2021-04-07 11:32:53.122161+00:00        -0.000288        -0.000288  ...
# 2021-04-07 11:32:54.122161+00:00        -0.000288        -0.000288  ...
#
#                                   asks_market_notional_9  \
# system_time
# 2021-04-07 11:32:50.122161+00:00                     0.0
# 2021-04-07 11:32:51.122161+00:00                     0.0
# 2021-04-07 11:32:52.122161+00:00                     0.0
# 2021-04-07 11:32:53.122161+00:00                     0.0
# 2021-04-07 11:32:54.122161+00:00                     0.0
#
#                                   asks_market_notional_10  \
# system_time
# 2021-04-07 11:32:50.122161+00:00                      0.0
# 2021-04-07 11:32:51.122161+00:00                      0.0
# 2021-04-07 11:32:52.122161+00:00                      0.0
# 2021-04-07 11:32:53.122161+00:00                      0.0
# 2021-04-07 11:32:54.122161+00:00                      0.0
#
#                                   asks_market_notional_11  \
# system_time
# 2021-04-07 11:32:50.122161+00:00                      0.0
# 2021-04-07 11:32:51.122161+00:00                      0.0
# 2021-04-07 11:32:52.122161+00:00                      0.0
# 2021-04-07 11:32:53.122161+00:00                      0.0
# 2021-04-07 11:32:54.122161+00:00                      0.0
#
#                                   asks_market_notional_12  \
# system_time
# 2021-04-07 11:32:50.122161+00:00                      0.0
# 2021-04-07 11:32:51.122161+00:00                      0.0
# 2021-04-07 11:32:52.122161+00:00                      0.0
# 2021-04-07 11:32:53.122161+00:00                      0.0
# 2021-04-07 11:32:54.122161+00:00                      0.0
#
#                                   asks_market_notional_13  \
# system_time
# 2021-04-07 11:32:50.122161+00:00                      0.0
# 2021-04-07 11:32:51.122161+00:00                      0.0
# 2021-04-07 11:32:52.122161+00:00                      0.0
# 2021-04-07 11:32:53.122161+00:00                      0.0
# 2021-04-07 11:32:54.122161+00:00                      0.0
#
#                                   asks_market_notional_14  eth_midpoint  \
# system_time
# 2021-04-07 11:32:50.122161+00:00                      0.0      1970.985
# 2021-04-07 11:32:51.122161+00:00                      0.0      1970.985
# 2021-04-07 11:32:52.122161+00:00                      0.0      1970.985
# 2021-04-07 11:32:53.122161+00:00                      0.0      1970.985
# 2021-04-07 11:32:54.122161+00:00                      0.0      1971.135
#
#                                   eth_spread  eth_bids_notional_0  \
# system_time
# 2021-04-07 11:32:50.122161+00:00        0.15              1.96000
# 2021-04-07 11:32:51.122161+00:00        0.15              1.96000
# 2021-04-07 11:32:52.122161+00:00        0.15              1.96000
# 2021-04-07 11:32:53.122161+00:00        0.15              1.96000
# 2021-04-07 11:32:54.122161+00:00        0.03           3242.48999
#
#                                   eth_asks_notional_0
# system_time
# 2021-04-07 11:32:50.122161+00:00          2330.929932
# 2021-04-07 11:32:51.122161+00:00          2330.929932
# 2021-04-07 11:32:52.122161+00:00          2330.929932
# 2021-04-07 11:32:53.122161+00:00          2330.929932
# 2021-04-07 11:32:54.122161+00:00          1103.839966
#
# [5 rows x 158 columns]

# %%
# ==========================================
# 3. Feature Engineering
# ==========================================
print("\n" + "=" * 50)
print("3. FEATURE ENGINEERING")
print("=" * 50)

window_short = 10   # 10-second rolling window
window_long  = 60   # 60-second rolling window

# ── BTC mid price ──────────────────────────────────────────
df['mid_price']   = df['midpoint']
df['log_return']  = np.log(df['mid_price'] / df['mid_price'].shift(1))

# ── BTC market state features ──────────────────────────────
df['btc_oimb_1'] = ( # Order Imbalance
    (df['bids_notional_0'] - df['asks_notional_0']) /
    (df['bids_notional_0'] + df['asks_notional_0'] + 1e-8)
)
df['btc_volatility_10s'] = df['log_return'].rolling(window_short).std()
df['btc_volatility_60s'] = df['log_return'].rolling(window_long).std()

df['btc_momentum_10s']   = df['log_return'].rolling(window_short).sum()
df['btc_momentum_60s']   = df['log_return'].rolling(window_long).sum()

# ── ETH cross-asset features ───────────────────────────────
df['eth_log_return'] = np.log(df['eth_midpoint'] / df['eth_midpoint'].shift(1))
df['eth_oimb_1'] = (
    (df['eth_bids_notional_0'] - df['eth_asks_notional_0']) /
    (df['eth_bids_notional_0'] + df['eth_asks_notional_0'] + 1e-8)
)
df['eth_volatility_10s'] = df['eth_log_return'].rolling(window_short).std()
df['eth_volatility_60s'] = df['eth_log_return'].rolling(window_long).std()
df['eth_momentum_10s']   = df['eth_log_return'].rolling(window_short).sum()
df['eth_momentum_60s']   = df['eth_log_return'].rolling(window_long).sum()

# ── BTC-ETH cross features ─────────────────────────────────
df['btc_eth_momentum_diff_10s'] = df['btc_momentum_10s'] - df['eth_momentum_10s']
df['btc_eth_momentum_diff_60s'] = df['btc_momentum_60s'] - df['eth_momentum_60s']

df['btc_eth_vol_ratio_10s']     = (
    df['btc_volatility_10s'] / (df['eth_volatility_10s'] + 1e-8)
)

# ── Prediction labels (BTC price direction, 10s ahead) ─────
prediction_horizon = 10
label_threshold    = 0.00015

df['future_return'] = (
    (df['mid_price'].shift(-prediction_horizon) - df['mid_price'])
    / df['mid_price']
)
df['label'] = np.select(
    [df['future_return'] >  label_threshold,
     df['future_return'] < -label_threshold],
    [1, -1],
    default=0
)

# Drop NaN rows generated by rolling windows and forward shift
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(f"Shape after dropna: {df.shape}")
print(f"Label distribution:\n{df['label'].value_counts().sort_index().to_string()}")

# Feature column lists (used downstream)
lob_features = []
for i in range(15):
    lob_features.extend([
        f'bids_distance_{i}', f'asks_distance_{i}',
        f'bids_notional_{i}', f'asks_notional_{i}'
    ])

market_state_cols = [
    # BTC
    'spread',            'btc_oimb_1',
    'btc_volatility_10s','btc_volatility_60s',
    'btc_momentum_10s',  'btc_momentum_60s',
    # ETH
    'eth_spread',        'eth_oimb_1',
    'eth_volatility_10s','eth_volatility_60s',
    'eth_momentum_10s',  'eth_momentum_60s',
    # BTC-ETH divergence
    'btc_eth_momentum_diff_10s',
    'btc_eth_momentum_diff_60s',
    'btc_eth_vol_ratio_10s',
]

print(f"\nLOB features   : {len(lob_features)}")
print(f"Market features: {len(market_state_cols)}")
# Out:
# ==================================================
# 3. FEATURE ENGINEERING
# ==================================================
# Shape after dropna: (99902, 176)
# Label distribution:
# label
# -1    21562
#  0    56846
#  1    21494
#
# LOB features   : 60
# Market features: 15

# %%
# ============================================================
# CLASSIC LOB FACTORS FROM ACADEMIC LITERATURE
# 在 Feature Engineering 之后运行
# ============================================================

eps = 1e-8

# ── Factor 1: Queue Imbalance (Cont, Kukanov & Stoikov 2014) ─
rho = 0.5
levels = 5
bid_cols = ['bids_notional_' + str(i) for i in range(levels)]
ask_cols = ['asks_notional_' + str(i) for i in range(levels)]
weights = np.exp(-rho * np.arange(levels))
weights /= weights.sum()
bid_mat = df[bid_cols].values
ask_mat = df[ask_cols].values
imb_mat = (bid_mat - ask_mat) / (bid_mat + ask_mat + eps)
df['factor_queue_imbalance'] = (imb_mat * weights).sum(axis=1)
print('Factor 1 done: factor_queue_imbalance')

# ── Factor 2: Order Flow Imbalance (Cont, Kukanov & Stoikov 2014) ─
bid_price = df['bids_distance_0']
ask_price = df['asks_distance_0']
bid_vol   = df['bids_notional_0']
ask_vol   = df['asks_notional_0']

e_bid = (
    bid_vol   * (bid_price >= bid_price.shift(1)).astype(float)
  - bid_vol.shift(1) * (bid_price <= bid_price.shift(1)).astype(float)
)
e_ask = (
    ask_vol.shift(1) * (ask_price >= ask_price.shift(1)).astype(float)
  - ask_vol   * (ask_price <= ask_price.shift(1)).astype(float)
)
df['factor_ofi'] = e_bid - e_ask
df['factor_ofi_10s'] = df['factor_ofi'].rolling(window_short).sum()
df['factor_ofi_60s'] = df['factor_ofi'].rolling(window_long).sum()
print('Factor 2 done: factor_ofi / factor_ofi_10s / factor_ofi_60s')

# ── Factor 3: Kyle Lambda (Kyle 1985) ─────────────────────────
delta_p   = df['log_return']
delta_ofi = df['factor_ofi'].fillna(0)
roll_cov  = delta_p.rolling(window_long).cov(delta_ofi)
roll_var  = delta_ofi.rolling(window_long).var()
df['factor_kyle_lambda'] = roll_cov / (roll_var + eps)
print('Factor 3 done: factor_kyle_lambda')

# ── Factor 4: LOB Depth Ratio (Gould et al. 2013) ────────────
levels_depth = 10
total_bid = df[['bids_notional_' + str(i) for i in range(levels_depth)]].sum(axis=1)
total_ask = df[['asks_notional_' + str(i) for i in range(levels_depth)]].sum(axis=1)
df['factor_depth_ratio']        = total_ask / (total_bid + eps)
df['factor_depth_imb']          = (total_bid - total_ask) / (total_bid + total_ask + eps)
df['factor_depth_ratio_smooth'] = df['factor_depth_ratio'].rolling(window_short).mean()
print('Factor 4 done: factor_depth_ratio / factor_depth_imb / factor_depth_ratio_smooth')

# ── Factor 5: Tick Rule (Lee & Ready 1991) ───────────────────
tick_sign = np.sign(df['log_return'].fillna(0))
tick_sign = tick_sign.replace(0, np.nan).ffill().fillna(1)
df['factor_tick_sign']          = tick_sign
df['factor_tick_momentum_10s']  = tick_sign.rolling(window_short).sum()
df['factor_tick_momentum_60s']  = tick_sign.rolling(window_long).sum()
print('Factor 5 done: factor_tick_sign / factor_tick_momentum_10s / factor_tick_momentum_60s')

# ── Factor 6: Amihud Illiquidity HF (Amihud 2002) ────────────
total_notional_t = (
    df[['bids_notional_' + str(i) for i in range(5)]].sum(axis=1)
  + df[['asks_notional_' + str(i) for i in range(5)]].sum(axis=1)
)
df['factor_amihud']     = np.abs(df['log_return']) / (total_notional_t + eps)
df['factor_amihud_60s'] = df['factor_amihud'].rolling(window_long).mean()
print('Factor 6 done: factor_amihud / factor_amihud_60s')

# ── 汇总 ──────────────────────────────────────────────────────
classic_factor_cols = [
    'factor_queue_imbalance',
    'factor_ofi', 'factor_ofi_10s', 'factor_ofi_60s',
    'factor_kyle_lambda',
    'factor_depth_ratio', 'factor_depth_imb', 'factor_depth_ratio_smooth',
    'factor_tick_sign', 'factor_tick_momentum_10s', 'factor_tick_momentum_60s',
    'factor_amihud', 'factor_amihud_60s',
]

df.dropna(subset=classic_factor_cols, inplace=True)
df.reset_index(drop=True, inplace=True)

print('Classic factors added:', len(classic_factor_cols))
print('df shape after adding factors:', df.shape)
# Out:
# Factor 1 done: factor_queue_imbalance
# Factor 2 done: factor_ofi / factor_ofi_10s / factor_ofi_60s
# Factor 3 done: factor_kyle_lambda
# Factor 4 done: factor_depth_ratio / factor_depth_imb / factor_depth_ratio_smooth
# Factor 5 done: factor_tick_sign / factor_tick_momentum_10s / factor_tick_momentum_60s
# Factor 6 done: factor_amihud / factor_amihud_60s
# Classic factors added: 13
# df shape after adding factors: (99842, 189)

# %%
print("Applying Rolling Z-Score to LOB features...")

roll_window = 3600

rolling_mean = df[lob_features].rolling(window=roll_window, min_periods=1).mean()
rolling_std  = df[lob_features].rolling(window=roll_window, min_periods=1).std()

df[lob_features] = (df[lob_features] - rolling_mean) / (rolling_std + 1e-8)
df.dropna(inplace=True)

print("Rolling Z-Score applied successfully.")

# ==========================================
# 4. PCA on BTC LOB Features
# ==========================================
print("\n" + "=" * 50)
print("4. PCA")
print("=" * 50)

X_lob     = df[lob_features].values
split_idx = int(len(df) * 0.8)        # chronological 80/20 split

X_train_lob = X_lob[:split_idx]
X_test_lob  = X_lob[split_idx:]

# # Standardise — fit on train only to prevent data leakage
# scaler         = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train_lob)
# X_test_scaled  = scaler.transform(X_test_lob)

# Retain components explaining 90% of variance
pca         = PCA(n_components=0.90, random_state=42)
# X_train_pca = pca.fit_transform(X_train_scaled)
# X_test_pca  = pca.transform(X_test_scaled)
X_train_pca = pca.fit_transform(X_train_lob)
X_test_pca  = pca.transform(X_test_lob)

print(f"LOB features : {len(lob_features)}")
print(f"PCA components retained (90% variance): {pca.n_components_}")
print(f"Train PCA shape: {X_train_pca.shape}")
print(f"Test  PCA shape: {X_test_pca.shape}")
# Out:
# Applying Rolling Z-Score to LOB features...
# Rolling Z-Score applied successfully.
#
# ==================================================
# 4. PCA
# ==================================================
# LOB features : 60
# PCA components retained (90% variance): 30
# Train PCA shape: (79872, 30)
# Test  PCA shape: (19969, 30)

# %%
# ==========================================
# 5. PCA Diagnostic Plots
# ==========================================
print("\n" + "=" * 50)
print("5. PCA DIAGNOSTICS")
print("=" * 50)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle("PCA Diagnostics — BTC LOB Features", fontsize=14)

# ── Scree plot ─────────────────────────────────────────────
axes[0].bar(range(1, pca.n_components_ + 1),
            pca.explained_variance_ratio_, color='steelblue')
axes[0].set_title("Explained Variance per Component")
axes[0].set_xlabel("Component"); axes[0].set_ylabel("Variance Ratio")
axes[0].grid(alpha=0.3)

# ── Cumulative variance ────────────────────────────────────
cum = pca.explained_variance_ratio_.cumsum()
axes[1].plot(range(1, pca.n_components_ + 1), cum, color='steelblue', marker='o', ms=4)
axes[1].axhline(0.90, color='tomato', linestyle='--', label='90% threshold')
axes[1].set_title("Cumulative Explained Variance")
axes[1].set_xlabel("Components"); axes[1].set_ylabel("Cumulative Variance")
axes[1].legend(); axes[1].grid(alpha=0.3)

# ── PC1 vs PC2 scatter by label ────────────────────────────
idx      = np.random.choice(len(X_train_pca), min(2000, len(X_train_pca)), replace=False)
y_train  = df['label'].iloc[:split_idx]
colors   = {1: 'steelblue', 0: 'gray', -1: 'tomato'}
labels_n = {1: 'Up', 0: 'Flat', -1: 'Down'}
for lbl, color in colors.items():
    mask = y_train.iloc[idx] == lbl
    axes[2].scatter(
        X_train_pca[idx][mask, 0],
        X_train_pca[idx][mask, 1],
        c=color, alpha=0.4, s=8, label=labels_n[lbl]
    )
axes[2].set_title("PC1 vs PC2 by Label")
axes[2].set_xlabel("PC1"); axes[2].set_ylabel("PC2")
axes[2].legend(); axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ==================================================
# 5. PCA DIAGNOSTICS
# ==================================================

# %%
# ==========================================
# 6 & 7. Final Dataset Assembly & Export
# ==========================================
from google.colab import drive
drive.mount('/content/drive')

print('=' * 50)
print('6 & 7. EXPORT DATASETS FOR ABLATION TO GOOGLE DRIVE')
print('=' * 50)

save_path = '/content/drive/MyDrive/629/'

# ── 补充定义 classic_factor_cols（若 factor cell 未运行则此处兜底）────
classic_factor_cols = [
    'factor_queue_imbalance',
    'factor_ofi',
    'factor_ofi_10s',
    'factor_ofi_60s',
    'factor_kyle_lambda',
    'factor_depth_ratio',
    'factor_depth_imb',
    'factor_depth_ratio_smooth',
    'factor_tick_sign',
    'factor_tick_momentum_10s',
    'factor_tick_momentum_60s',
    'factor_amihud',
    'factor_amihud_60s',
]
# 只保留实际存在于 df 中的列（防止 factor cell 未跑时报错）
classic_factor_cols = [c for c in classic_factor_cols if c in df.columns]
print('Classic factors found in df:', len(classic_factor_cols))

# ── PCA 截断到前 N 个主成分 ──────────────────────────────────
kaiser_n  = int(np.sum(pca.explained_variance_ > 1))
top_n_pca = min(kaiser_n, 10)

print('PCA components (90% var): ' + str(pca.n_components_))
print('Kaiser criterion (lam>1): ' + str(kaiser_n))
print('Using top N PCs         : ' + str(top_n_pca))
print('Cumulative variance     : ' + str(round(float(pca.explained_variance_ratio_[:top_n_pca].sum()), 3)))

pca_cols_all  = ['pca_' + str(i+1) for i in range(pca.n_components_)]
pca_cols_topn = ['pca_' + str(i+1) for i in range(top_n_pca)]

pca_df_full = pd.DataFrame(
    np.vstack((X_train_pca, X_test_pca)),
    columns=pca_cols_all,
    index=df.index
)
pca_df = pca_df_full[pca_cols_topn]

# ── Common columns ────────────────────────────────────────────
common_cols = pd.DataFrame({
    'label':         df['label'].values,
    'future_return': df['future_return'].values,
    'split':         ['train'] * split_idx + ['test'] * (len(df) - split_idx)
}, index=df.index)

# ── Dataset A: Full (PCA top-N + Market + Classic) ────────────
df_full = pd.concat([pca_df, df[market_state_cols], df[classic_factor_cols], common_cols], axis=1)
df_full.to_csv(save_path + 'lob_full.csv', index=False)
print('Saved -> ' + save_path + 'lob_full.csv       | Shape: ' + str(df_full.shape))
print('  = PCA(' + str(top_n_pca) + ') + market(' + str(len(market_state_cols)) + ') + classic(' + str(len(classic_factor_cols)) + ') + label(3)')

# ── Dataset B: No PCA (Raw LOB + Market + Classic) ────────────
df_no_pca = pd.concat([df[lob_features], df[market_state_cols], df[classic_factor_cols], common_cols], axis=1)
df_no_pca.to_csv(save_path + 'lob_no_pca.csv', index=False)
print('Saved -> ' + save_path + 'lob_no_pca.csv    | Shape: ' + str(df_no_pca.shape))
print('  = raw_LOB(' + str(len(lob_features)) + ') + market(' + str(len(market_state_cols)) + ') + classic(' + str(len(classic_factor_cols)) + ') + label(3)')

# ── Dataset C: No Market (PCA top-N + Classic only) ───────────
df_no_market = pd.concat([pca_df, df[classic_factor_cols], common_cols], axis=1)
df_no_market.to_csv(save_path + 'lob_no_market.csv', index=False)
print('Saved -> ' + save_path + 'lob_no_market.csv | Shape: ' + str(df_no_market.shape))
print('  = PCA(' + str(top_n_pca) + ') + classic(' + str(len(classic_factor_cols)) + ') + label(3)')

print('Data preparation complete! Ready for PyTorch ablation studies.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ==================================================
# 6 & 7. EXPORT DATASETS FOR ABLATION TO GOOGLE DRIVE
# ==================================================
# Classic factors found in df: 13
# PCA components (90% var): 30
# Kaiser criterion (lam>1): 17
# Using top N PCs         : 10
# Cumulative variance     : 0.601
# Saved -> /content/drive/MyDrive/629/lob_full.csv       | Shape: (99841, 41)
#   = PCA(10) + market(15) + classic(13) + label(3)
# Saved -> /content/drive/MyDrive/629/lob_no_pca.csv    | Shape: (99841, 91)
#   = raw_LOB(60) + market(15) + classic(13) + label(3)
# Saved -> /content/drive/MyDrive/629/lob_no_market.csv | Shape: (99841, 26)
#   = PCA(10) + classic(13) + label(3)
# Data preparation complete! Ready for PyTorch ablation studies.
